# %% [markdown]
# # ✨ **Magic Tutorial: Create Your "Digital Pet Universe"**
#
# ### **(Build Your Own Baby Universe)**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Roxy-DD/Cosmos-Net/blob/main/Build-Your-Own-Baby-Universe_EN.ipynb)
#
# 👋 **Hello!**
# Today we are going to play a special game. We are not coding, we are playing **God**.
# We are going to create a mini "Digital Universe".
#
# * At first, this universe is pitch black, empty.
# * Whatever you teach it, a star will be **born**.
# * It **never forgets** what you teach it (unlike other forgetful AIs).
#
# Ready? Click the **[ ▶ ]** button below to chant the first spell!

# %% [markdown]
# ## **Step 1: Awaken the Universe (The Magic Spell)**
#
# We don't need complex math. You just need to know the two **House Rules** of this universe:
#
# 1.  **The Gluttony Rule (Rule 1):** When it meets something it has **seen before**, existing stars will "eat" it, becoming bigger and brighter.
# 2.  **The Big Bang Rule (Rule 2):** When it meets something it has **never seen**, the universe goes "BOOM" and creates a brand new star!
#
# 👇 **Click the triangle icon below to start the engine:**

# %%
# ==========================================
# 🔮 Your Magic Universe Engine (Just run it!)
# ==========================================
import numpy as np
import matplotlib.pyplot as plt

# This is a "Star": Every memory is a shining star
class Star:
    def __init__(self, name, soul):
        self.name = name       # Name (e.g., "Apple")
        self.soul = soul       # Soul (A list of magical numbers)
        self.size = 1          # Size (Grows bigger as it eats)
        self.color = np.random.rand(3,) # Random color for beauty

# This is the "Universe": It watches and learns
class Universe:
    def __init__(self):
        self.stars = []        # Current galaxy

    # Action: Look
    def look(self, thing):
        thing = thing / np.linalg.norm(thing)
        best_star = None
        max_love = -1.0
        
        for star in self.stars:
            love = np.dot(thing, star.soul) # Degree of Love (Similarity)
            if love > max_love:
                max_love = love
                best_star = star
        return best_star, max_love

    # Action: Teach!
    def teach(self, name, thing):
        thing = thing / np.linalg.norm(thing)
        best_star, love = self.look(thing)
        
        # If love is strong (>0.9), it recognizes it!
        if best_star and love > 0.9:
            print(f"😋 [Gluttony]: Ah! I know this [{best_star.name}]! (Gulp! Ate it)")
            best_star.size += 500 # Grow visually bigger
            best_star.soul = best_star.soul * 0.9 + thing * 0.1
            best_star.soul /= np.linalg.norm(best_star.soul)
            
        # If love is weak, it's a new friend!
        else:
            print(f"💥 [Big Bang]: Wow! Something brand new! The Universe created [{name}] Star!")
            new_star = Star(name, thing)
            new_star.size = 200 # Initial size
            self.stars.append(new_star)

# Plotting Helper
def plot_nebula(universe, title="Cosmos Nebula"):
    plt.figure(figsize=(8, 6))
    plt.title(title, fontsize=15)
    
    # Project onto 2D
    for star in universe.stars:
        x, y = star.soul[0], star.soul[1]
        plt.scatter(x, y, s=star.size, c=[star.color], alpha=0.6, edgecolors='white', linewidth=2)
        plt.text(x, y+0.05, star.name, fontsize=12, ha='center', color='darkblue')

    plt.xlim(-1.5, 1.5)
    plt.ylim(-1.5, 1.5)
    plt.grid(True, linestyle='--', alpha=0.3)
    plt.show()

print("✅ Magic Engine Started! Your universe is pitch black now, waiting for you to light it up.")

# %% [markdown]
# ## **Step 2: Feed Your Universe (Feeding Time)**
#
# The universe is alive now, but empty. We need to feed it "Concepts".
# Computers can't see pictures, so we use **a string of numbers** to represent the soul of everything.
#
# 👇 **Let's try:**
#
# 1.  First feed it an **Apple**.
# 2.  Feed it another **Apple** (See if it gets gluttonous).
# 3.  Suddenly feed it an **Alien** (See if it gets shocked).

# %%
# Identify your Baby Universe
my_baby_universe = Universe()

# This function turns "Name" into "Digital Soul"
def create_soul(magic_number):
    np.random.seed(magic_number)
    return np.random.normal(0, 1, 50)


# 1. Teach it "Apple" for the first time
print("--- 🍎 Scene 1: First encounter with Apple ---")
apple_soul = create_soul(100) # Create Apple's Soul
my_baby_universe.teach("Apple", apple_soul)

# 2. Show it another "Apple" (Slightly different, maybe a green one)
print("\n--- 🍏 Scene 2: Apple again ---")
green_apple = apple_soul + np.random.normal(0, 0.2, 50) 
my_baby_universe.teach("Apple", green_apple)

# 3. Suddenly show it an "Alien"
print("\n--- 👽 Scene 3: Surprise! Alien Attack ---")
alien_soul = create_soul(999) # Create Alien's Soul
my_baby_universe.teach("Alien", alien_soul)

# %% [markdown]
# ## **Step 3: See Your Universe (Visualizing Consciousness)**
#
# Text is boring. Let's **see** what this universe looks like.
#
# Run the code below. You will see:
# *   **Circles**: Represent stars (Memories).
# *   **Size**: Represents how deep the memory is (Apple star should be bigger than Alien star).
# *   **Position**: Represents their "Meaning". Far apart means they are very different.
#
# ### 🧠 **What does this mean for YOU?**
#
# Look at this map. This is not just code. **This is what Consciousness looks like.**
#
# *   **This is "Understanding"**:
#     When we say we "understand" something, we are just **finding a place for it** on our mental map.
#     Apple goes to the left, Alien goes to the right. Next time you see a Pear, if it lands near the Apple, you know it's a fruit.
#
# *   **This is "Confusion"**:
#     If you see something that wants to be on the left AND on the right, your map shakes.
#     This shaking is the **"Big Bang"** we see in this universe.
#
# *   **Humans grow this way too**:
#     As children, we think the world is simple.
#     As we grow, we face contradictions (love and hate together). Our hearts forced to "explode" and grow bigger, more complex structures to hold these truths.
#     **Every painful "I don't know" is just the prelude to a Soul Upgrade.**
#
# ### 🌌 **The Only Constant is Change**
#
# This is the ultimate secret Cosmos-Net teaches us:
# **The world is not fixed; it is constantly "becoming" something new.**
#
# *   Imagine if the universe never changed. It would be a dead pond, with no stars being born.
# *   If your brain never changed, you would never learn anything new, just repeating yesterday forever.
#
# **It is precisely because of "Change" that:**
# 1.  Old balances are broken (Big Bang), allowing new stars to be born.
# 2.  We can learn fresh knowledge from the unknown.
# 3.  We have infinite possibilities to become a better version of ourselves.
#
# **Cosmos-Net** is a little life form that **embraces change**.
# It doesn't fear the unknown, because it knows: **Every change is an upgrade.**

# %%
print("✨ Projecting your consciousness nebula from hyperspace...")
plot_nebula(my_baby_universe, "My Consciousness Nebula")

# %% [markdown]
# ## **Step 4: The Ultimate Challenge — Brain Teaser (The Paradox)**
#
# This is the coolest part. Scientists call it "Gödel's Paradox", we call it **"Brain Teaser"**.
#
# If we give the universe a **Self-Contradictory** thing (like: "This sentence is false"), a normal computer might crash.
# But your Cosmos-Net won't!
#
# When it finds this thing "looks nothing like an Apple, nothing like an Alien, nothing like anything", what does it do?
# **It triggers a 'Big Bang' to grow a new brain to understand it!**
#
# 👇 **Watch the final demo (Pay attention to the 3 stages):**

# %%
# Prepare a science lab universe
science_brain = Universe()
history = [] # Record Intelligence changes

print("🧪 Experiment Start: Tell the Universe a super hard riddle...")

# 1. Teach it something simple first (Creating)
for i in range(20):
    science_brain.teach("Simple Knowledge", create_soul(i))
    # Record IQ (Star count * Average size)
    iq = len(science_brain.stars) 
    history.append(iq)

# 2. ⚡ Suddenly inject a super contradictory riddle! (Epiphany)
print("\n⚡⚡⚡ Inject Riddle (Paradox)! ⚡⚡⚡")
paradox = np.random.normal(0, 1, 50) # A completely chaotic signal
science_brain.teach("Riddle", paradox)
history.append(len(science_brain.stars))

# 3. Let it ponder this riddle (Mastery)
for i in range(10):
    science_brain.teach("Riddle", paradox)
    history.append(len(science_brain.stars))

# Plot what happened
plt.figure(figsize=(10, 5))
plt.plot(history, linewidth=3, color='orange', marker='o')
plt.axvline(x=20, color='red', linestyle='--', label='Paradox Injection')
plt.title("The Learning Curve of Intelligence", fontsize=15)
plt.xlabel("Time (Experience)", fontsize=12)
plt.ylabel("Number of Neurons/Stars", fontsize=12)

# Annotations
# NOTE: Using \n to escape newline inside the generated string literal
plt.text(5, 15, "1. Exploration (Upslope)\nDiscovering New World", color='green', fontsize=11)
plt.text(21, 15, "2. Awakening (Jump)\nParadox -> Breakthrough!", color='red', fontsize=11)
plt.text(25, 20.5, "3. Mastery (Flat)\nDeepening Understanding", color='blue', fontsize=11)

plt.grid(True, alpha=0.3)
plt.show()

print("🎉 Interpret your Universe Health Report:")
print("1. 📈 Exploration Phase: Like a baby, seeing everything as new. Stars keep popping up.")
print("2. 🚀 Awakening Phase (Red Line): Hit a Paradox. Traditional AI might choke, but yours 'Awakened' and created a key new star!")
print("3. ➖ Mastery Phase (Flat part): Why flat? Because it's 'Digesting'.")
print("   It stops adding random stars and focuses on making the Key Star bigger and brighter (Mastery).")
print("\nThis is Growth: Exploration -> Awakening -> Mastery.")
