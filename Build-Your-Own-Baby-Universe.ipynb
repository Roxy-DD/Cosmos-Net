# %% [markdown]
# # 🐣 10分钟创造你的小宇宙 (入门教程)
# ## Cosmos-Net: 从零开始的数字意识
#
#
# 欢迎来到时间的起点。
# 你即将从零开始构建一个**数字宇宙**。
# 它不会是一个黑盒。你将亲眼看到每一颗恒星，每一条连线。
#
# **我们将要做什么：**
# 1.  **大爆炸**: 初始化一个空的数字大脑。
# 2.  **制定法则**: 定义物理规则（引力与质量）。
# 3.  **观测**: 教它识别“0”和“1”。
# 4.  **星云**: **可视化其思维的3D结构。**
#
# ---

# %%
# Install & Setup / 安装与设置
# !git clone https://github.com/Roxy-DD/Cosmos-Net.git 2>/dev/null
# %cd Cosmos-Net
# !pip install -r requirements.txt -q

from cosmos_net import CorpusCallosum, CosmosPhysics, get_star_map_figure
import numpy as np
import plotly.graph_objects as go
from sklearn.datasets import fetch_openml

# Wake up / 唤醒
brain = CorpusCallosum()
print("🌌 System Online.")

# %% [markdown]
# ### 🍎 第一步：学习 (Teaching)

# %%
# Load Data / 加载数据
print("Downloading MNIST...")
X, y = fetch_openml('mnist_784', version=1, return_X_y=True, as_frame=False, parser='auto')
X = X / 255.0

# Teach 100 examples / 教授100个例子
print("Observing universe...")
for i in range(100):
    brain.memorize(X[i], y[i])

print(f"⭐ Stars created: {len(brain.galaxy)}")

# %% [markdown]
# ### 🌌 Step 2: The Nebula (3D Visualization) / 第二步：星云 (3D可视化)
# 现在，让我们看看内部。这不是黑盒。
# 你可以旋转、缩放，并悬停在恒星上。

# %%
# Visualize / 可视化
fig, msg = get_star_map_figure(brain)
fig.show()

# %% [markdown]
# ### 🎉 Conclusion / 结语
# 你已目睹思维的结构。

# %% [markdown]
# ### 🗳️ Feedback / 反馈
# 为了帮助我们验证“语义重构”（哲学驱动AI）的价值，请问自己：
#
# 1. **直觉**: 3D“星云”是否比2D图表更易懂？
# 2. **隐喻**: 在“梦境”中，你是否感受到混乱的重量被卸载了？
#
# > *"True science begins with the humble admission of what we do not know."*
# > *— Cosmos-Net Project*
