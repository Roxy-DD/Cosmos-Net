# %% [markdown]
# # 🧠 双脑心智与梦境时光 (进阶教程)
# ## 进阶之旅：逻辑、直觉与睡眠
#
#
# 欢迎来到更深层。
# 我们知道大脑会学习。但它是如何**睡眠**的？它是如何处理**冲突**的？
# 我们将探索**双脑心智**（左右脑）和**梦境时光**。
#
# **核心概念：**
# *   **左脑**: 逻辑，统计 (图书管理员)。
# *   **右脑**: 直觉，几何 (艺术家)。
# *   **睡眠**: 融合记忆，凝练智慧。
#
# ---

# %%
# Install & Setup / 安装与设置
# !git clone https://github.com/Roxy-DD/Cosmos-Net.git 2>/dev/null
# %cd Cosmos-Net
# !pip install -r requirements.txt -q

from cosmos_net import CorpusCallosum, CosmosPhysics, get_star_map_figure
import numpy as np
import plotly.graph_objects as go
from sklearn.datasets import fetch_openml

# Wake up / 唤醒
brain = CorpusCallosum()
print("🌌 System Online.")

# %% [markdown]
# ### ⚔️ Step 1: Conflict & Chaos / 第一步：冲突与混沌
# 我们将用噪音过载大脑，创造一个“混乱的心智”。

# %%
# Create Chaos / 制造混乱
print("Generating noise...")
base_vec = np.random.rand(784)
for i in range(200):
    # Create slightly different variations of the same thing
    noise = np.random.normal(0, 0.2, 784)
    brain.memorize(base_vec + noise, 'Chaos')

print(f"Stars: {len(brain.galaxy)} (High Entropy)")

# Show the Messy Nebula / 展示混乱的星云
fig, msg = get_star_map_figure(brain)
fig.show()

# %% [markdown]
# ### 💤 Step 2: The Dreamtime / 第二步：梦境时光
# 现在我们睡眠。大脑将修剪弱者，融合相似者。
# 看着熵值下降。

# %%
# Dream / 做梦
print("💤 Entering Dreamtime...")
report = brain.dream()
print(report)

# Show the Crystal Nebula / 展示晶体般的星云
fig, msg = get_star_map_figure(brain)
fig.show()

# %% [markdown]
# ### 🎉 Conclusion / 结语
# 你已目睹思维的结构。
